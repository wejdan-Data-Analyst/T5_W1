# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/T5/WEEK 1/Exam/Task (1) Dataset.csv")

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.count()
# Out:
# Time                           12316
# Day_of_week                    12316
# Age_band_of_driver             12316
# Sex_of_driver                  12316
# Educational_level              11575
# Vehicle_driver_relation        11737
# Driving_experience             11487
# Type_of_vehicle                11366
# Owner_of_vehicle               11834
# Service_year_of_vehicle         8388
# Defect_of_vehicle               7889
# Area_accident_occured          12077
# Lanes_or_Medians               11931
# Road_allignment                12174
# Types_of_Junction              11429
# Road_surface_type              12144
# Road_surface_conditions        12316
# Light_conditions               12316
# Weather_conditions             12316
# Type_of_collision              12161
# Number_of_vehicles_involved    12316
# Number_of_casualties           12316
# Vehicle_movement               12008
# Casualty_class                 12316
# Sex_of_casualty                12316
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df=df.drop(['Defect_of_vehicle'],axis=1)
df=df.drop(['Work_of_casuality'],axis=1)
df=df.drop(['Fitness_of_casuality'],axis=1)
df=df.drop(['Service_year_of_vehicle'],axis=1)

# %%
df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])
df['Driving_experience']=df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])
df['Type_of_vehicle']=df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])
df['Owner_of_vehicle']=df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0])
df['Area_accident_occured']=df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0])
df['Road_allignment']=df['Road_allignment'].fillna(df['Road_allignment'].mode()[0])
df['Type_of_collision']=df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0])
df['Vehicle_movement']=df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0])
df['Road_surface_type']=df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0])
df['Educational_level']=df['Educational_level'].fillna(df['Educational_level'].mode()[0])
df['Types_of_Junction']=df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])
df['Lanes_or_Medians']=df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df.count()
# Out:
# Time                           12316
# Day_of_week                    12316
# Age_band_of_driver             12316
# Sex_of_driver                  12316
# Educational_level              12316
# Vehicle_driver_relation        12316
# Driving_experience             12316
# Type_of_vehicle                12316
# Owner_of_vehicle               12316
# Area_accident_occured          12316
# Lanes_or_Medians               12316
# Road_allignment                12316
# Types_of_Junction              12316
# Road_surface_type              12316
# Road_surface_conditions        12316
# Light_conditions               12316
# Weather_conditions             12316
# Type_of_collision              12316
# Number_of_vehicles_involved    12316
# Number_of_casualties           12316
# Vehicle_movement               12316
# Casualty_class                 12316
# Sex_of_casualty                12316
# Age_band_of_casualty           12316
# Casualty_severity              12316
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Driving_experience']=df['Driving_experience'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df['Driving_experience']=df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])

# %%
df['Driving_experience'] = df['Driving_experience'].astype(int)

# %%
df['Age_band_of_driver']=df['Age_band_of_driver'].str.extract(r'(\d+\.?\d*)').astype(float)
df['Age_band_of_driver']=df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mode()[0])
df['Age_band_of_driver'] = df['Age_band_of_driver'].astype(int)

# %%
df.head(10)
# Out:
#        Time Day_of_week  Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday                  18          Male   Above high school
# 1  17:02:00      Monday                  31          Male  Junior high school
# 2  17:02:00      Monday                  18          Male  Junior high school
# 3   1:06:00      Sunday                  18          Male  Junior high school
# 4   1:06:00      Sunday                  18          Male  Junior high school
# 5  14:15:00      Friday                  31          Male  Junior high school
# 6  17:30:00   Wednesday                  18          Male  Junior high school
# 7  17:20:00      Friday                  18          Male  Junior high school
# 8  17:20:00      Friday                  18          Male  Junior high school
# 9  17:20:00      Friday                  18          Male  Junior high school
#
#   Vehicle_driver_relation  Driving_experience      Type_of_vehicle  \
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Area_accident_occured        12316 non-null  object
#  10  Lanes_or_Medians             12316 non-null  object
#  11  Road_allignment              12316 non-null  object
#  12  Types_of_Junction            12316 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
numiracal_column=['Number_of_vehicles_involved'	,'Number_of_casualties']

numerical_df=df[numiracal_column]

correlation_matrix=numerical_df.corr()

print(correlation_matrix)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from pickle import TRUE
plt.Figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True)
plt.title("correlation matrix plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Age_band_of_driver', data=df, palette='viridis')
plt.title('Distribution of Age Bands of Drivers')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-112-902e55a541f7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age_band_of_driver', data=df, palette='viridis')

# %%
plt.figure(figsize=(10,4))
plt.xticks(size=8)
plt.yticks(size=8)
sns.countplot(data=df, y='Type_of_vehicle', order=df['Type_of_vehicle'].value_counts().index[:3])

ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), \
                ha='left', va='center', fontsize=8, color='black', xytext=(5, 0), textcoords='offset points')

plt.title('Top 3 Type of vehicle')
plt.show()

# %%
grouped_data=df.groupby('Type_of_vehicle')['Age_band_of_driver'].count()
print(grouped_data)
# Out:
# Type_of_vehicle
# Automobile              4155
# Bajaj                     29
# Bicycle                   21
# Long lorry               383
# Lorry (11?40Q)           541
# Lorry (41?100Q)         2186
# Motorcycle               177
# Other                   1208
# Pick up upto 10Q         811
# Public (12 seats)        711
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Ridden horse              76
# Special vehicle           84
# Stationwagen             687
# Taxi                     265
# Turbo                     46
# Name: Age_band_of_driver, dtype: int64

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
grouped_data=df.groupby('Accident_severity')['Age_band_of_driver'].count()
print(grouped_data)
# Out:
# Accident_severity
# Fatal injury        158
# Serious Injury     1743
# Slight Injury     10415
# Name: Age_band_of_driver, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_band_of_driver', hue='Accident_severity')
plt.title('Accident Severity by Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count of Accidents')
plt.legend(title='Accident Severity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(8, 8))
plt.pie(grouped_data, labels=grouped_data.index, autopct='%1.1f%%',)
plt.title('Distribution of Age Bands of Drivers by Type of Vehicle')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# The dataset contained alot of null values that needed handling.
# i noticed incostinsies in columns[Driving_experience ,Age_band_of_driver] after fixing it ,noticed it has null value that need handling also it neede type fixing so i change it to int
#based on the visual of Accident Severity by Age Band of Driver we can see that the must number of accedint is by people under 30 years old BUT ITS MOSTLY slight injury
#work force mostly young people
#Top 3 Type of vehicle is : atonomes
